# %%
from joblib import load

# Load the three models
classifier = load('./wildfire_spread_classifier_advanced.joblib')
regressor = load('./wildfire_spread_regressor_advanced.joblib')
direction_predictor = load('./wildfire_direction_predictor.joblib')

# Make predictions
spread_pred = classifier.predict(X)
intensity_pred = regressor.predict(X)
direction_pred = direction_predictor.predict(X)

print("Spread predictions shape:", spread_pred.shape)
print("Spread predictions sample:", spread_pred[:5])

print("\nIntensity predictions shape:", intensity_pred.shape)
print("Intensity predictions sample:", intensity_pred[:5])

print("\nDirection predictions shape:", direction_pred.shape)
print("Direction predictions sample:", direction_pred[:5])

# %%
import numpy as np

# Load the data files
X = np.load('./X.npy')
y = np.load('./y.npy')

# Examine shapes and sample data
print("X shape:", X.shape)
print("X sample 1):\n", X[:1])
print("\nX data type:", X.dtype)

print("\ny shape:", y.shape)
print("y sample (first 1 value):", y[:1])
print("y data type:", y.dtype)
# Out:
# X shape: (15992, 23)
# X sample 1):
#  [[ 8.50275879e+01  1.41000000e+02  1.74233849e+02  1.90257690e+02
#    3.02863784e+00  3.32679176e+00  2.75738490e+02  2.76462402e+02
#    2.92976338e+02  2.93491241e+02  4.58782247e-03  4.74198023e-03
#    3.71829310e+00  4.98864698e+00  7.52023608e+03  8.54800000e+03
#    1.10000000e+01  2.68554688e-03 -3.01331365e+00  3.04282794e-01
#    2.57517770e+02  2.79624419e+04  2.34999988e+00]]
#
# X data type: float64
#
# y shape: (15992,)
# y sample (first 1 value): [260.27305102]
# y data type: float64
